# %% [markdown]
# <a href="https://colab.research.google.com/github/FranklinW10/MLGamePred/blob/main/BaseballMLWalkthough.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pybaseball
import os
import pandas as pd
import numpy as np
from pybaseball import batting_stats
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 426.1/426.1 kB 7.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.5/410.5 kB 24.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 856.7/856.7 kB 37.7 MB/s eta 0:00:00
# ...

# %%
START = 2005
END = 2025

# %%
batting = batting_stats(START, END, qual=200)

# %%
batting.to_csv("batting.csv")

# %%
batting = batting.groupby("IDfg", group_keys = False).filter(lambda x: x.shape[0]>1)
batting
# Out:
#        IDfg  Season                 Name   Team  Age    G   AB   PA    H   1B  \
# 1     15640    2024          Aaron Judge    NYY   32  158  559  704  180   85
# 4     15640    2022          Aaron Judge    NYY   30  157  570  696  177   87
# 141   25764    2024       Bobby Witt Jr.    KCR   24  161  636  709  211  123
# 9     13611    2018         Mookie Betts    BOS   25  136  520  614  180   96
# 63    10155    2013           Mike Trout    LAA   21  157  589  716  190  115
# ...     ...     ...                  ...    ...  ...  ...  ...  ...  ...  ...
# 6340   8585    2009  Yuniesky Betancourt  - - -   27  134  470  508  115   83
# 6363     45    2012          Rod Barajas    PIT   36  104  321  361   66   44
# 6897   9272    2018          Chris Davis    BAL   32  128  470  522   79   51
# 6513    319    2011            Adam Dunn    CHW   31  122  415  496   66   39
# 863    2113    2008          Ryan Doumit    PIT   27  116  431  465  137   88
#
# ...

# %%
def next_season(player):
    player = player.sort_values("Season")
    player["Next_WAR"] = player["WAR"].shift(-1)
    return player
batting = batting.groupby("IDfg", group_keys=False).apply(next_season)
# Out:
# <ipython-input-6-2b72d6ca2b95>:5: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   batting = batting.groupby("IDfg", group_keys=False).apply(next_season)

# %%
batting[["Name","Season","WAR","Next_WAR"]]
# Out:
#                   Name  Season  WAR  Next_WAR
# 5356   Alfredo Amezaga    2006  1.1       2.0
# 4792   Alfredo Amezaga    2007  2.0       1.2
# 5031   Alfredo Amezaga    2008  1.2       NaN
# 3958   Garret Anderson    2005 -0.2       0.1
# 3733   Garret Anderson    2006  0.1       1.4
# ...                ...     ...  ...       ...
# 2480  Masataka Yoshida    2024  0.8       NaN
# 3975    Nolan Schanuel    2024  0.7       0.8
# 2518    Nolan Schanuel    2025  0.8       NaN
# 3565    Wyatt Langford    2024  2.9       1.0
# 3726    Wyatt Langford    2025  1.0       NaN
#
# [6644 rows x 4 columns]

# %%
null_count = batting.isnull().sum()
null_count
# Out:
# IDfg           0
# Season         0
# Name           0
# Team           0
# Age            0
#             ...
# xBA         6644
# xSLG        6644
# xwOBA       6644
# L-WAR          0
# Next_WAR    1198
# Length: 321, dtype: int64

# %%
complete_cols = list(batting.columns[null_count == 0])

# %%
complete_cols
# Out:
# ['IDfg',
#  'Season',
#  'Name',
#  'Team',
#  'Age',
#  'G',
#  'AB',
#  'PA',
#  'H',
#  '1B',
#  '2B',
#  '3B',
#  'HR',
#  'R',
#  'RBI',
#  'BB',
#  'IBB',
#  'SO',
#  'HBP',
#  'SF',
#  'SH',
#  'GDP',
#  'SB',
#  'CS',
#  'AVG',
#  'GB',
#  'FB',
#  'LD',
#  'IFFB',
#  'Pitches',
#  'Balls',
#  'Strikes',
#  'IFH',
#  'BU',
#  'BUH',
#  'BB%',
#  'K%',
#  'BB/K',
#  'OBP',
#  'SLG',
#  'OPS',
#  'ISO',
#  'BABIP',
#  'GB/FB',
#  'LD%',
#  'GB%',
#  'FB%',
#  'IFFB%',
#  'HR/FB',
#  'IFH%',
#  'BUH%',
#  'wOBA',
#  'wRAA',
#  'wRC',
#  'Bat',
#  'Rep',
#  'Pos',
#  'RAR',
#  'WAR',
#  'Dol',
#  'Spd',
#  'wRC+',
#  'WPA',
#  '-WPA',
#  '+WPA',
#  'RE24',
#  'REW',
#  'pLI',
#  'PH',
#  'WPA/LI',
#  'Clutch',
#  'FB% (Pitch)',
#  'FBv',
#  'SL%',
#  'SLv',
#  'CT%',
#  'CTv',
#  'CB%',
#  'CBv',
#  'CH%',
#  'CHv',
#  'wFB',
#  'wSL',
#  'wCT',
#  'wCB',
#  'wCH',
#  'wFB/C',
#  'wSL/C',
#  'wCT/C',
#  'wCB/C',
#  'wCH/C',
#  'O-Swing%',
#  'Z-Swing%',
#  'Swing%',
# ...

# %%
batting = batting[complete_cols + ["Next_WAR"]].copy()
batting
# Out:
#        IDfg  Season              Name Team  Age    G   AB   PA    H   1B  ...  \
# 5356      1    2006   Alfredo Amezaga  FLA   28  132  334  378   87   72  ...
# 4792      1    2007   Alfredo Amezaga  FLA   29  133  400  448  105   80  ...
# 5031      1    2008   Alfredo Amezaga  FLA   30  125  311  337   82   61  ...
# 3958      2    2005   Garret Anderson  LAA   33  142  575  603  163  111  ...
# 3733      2    2006   Garret Anderson  LAA   34  141  543  588  152  105  ...
# ...     ...     ...               ...  ...  ...  ...  ...  ...  ...  ...  ...
# 2480  31837    2024  Masataka Yoshida  BOS   30  108  378  421  106   75  ...
# 3975  33189    2024    Nolan Schanuel  LAA   22  147  519  607  130   98  ...
# 2518  33189    2025    Nolan Schanuel  LAA   23   62  217  256   59   42  ...
# 3565  33333    2024    Wyatt Langford  TEX   22  134  499  557  126   81  ...
# 3726  33333    2025    Wyatt Langford  TEX   23   55  207  235   47   28  ...
#
# ...

# %%
batting.dtypes
# Out:
# IDfg          int64
# Season        int64
# Name         object
# Team         object
# Age           int64
#              ...
# Events        int64
# CStr%       float64
# CSW%        float64
# L-WAR       float64
# Next_WAR    float64
# Length: 135, dtype: object

# %%
del batting["Dol"]
del batting["Age Rng"]

# %%
batting["team_code"] = batting["Team"].astype("category").cat.codes
batting
# Out:
#        IDfg  Season              Name Team  Age    G   AB   PA    H   1B  ...  \
# 5356      1    2006   Alfredo Amezaga  FLA   28  132  334  378   87   72  ...
# 4792      1    2007   Alfredo Amezaga  FLA   29  133  400  448  105   80  ...
# 5031      1    2008   Alfredo Amezaga  FLA   30  125  311  337   82   61  ...
# 3958      2    2005   Garret Anderson  LAA   33  142  575  603  163  111  ...
# 3733      2    2006   Garret Anderson  LAA   34  141  543  588  152  105  ...
# ...     ...     ...               ...  ...  ...  ...  ...  ...  ...  ...  ...
# 2480  31837    2024  Masataka Yoshida  BOS   30  108  378  421  106   75  ...
# 3975  33189    2024    Nolan Schanuel  LAA   22  147  519  607  130   98  ...
# 2518  33189    2025    Nolan Schanuel  LAA   23   62  217  256   59   42  ...
# 3565  33333    2024    Wyatt Langford  TEX   22  134  499  557  126   81  ...
# 3726  33333    2025    Wyatt Langford  TEX   23   55  207  235   47   28  ...
#
# ...

# %%
batting_full = batting.copy()
batting = batting.dropna().copy()

# %%
from sklearn.linear_model import Ridge
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.model_selection import TimeSeriesSplit

rr = Ridge(alpha=1)


split = TimeSeriesSplit(n_splits=3)

sfs = SequentialFeatureSelector(rr,
                                n_features_to_select=20,
                                direction="forward",
                                cv=split, n_jobs = 4)

# %%
removed_columns = ["Next_WAR", "Name", "Team", "IDfg", "Season"]
selected_columns = batting.columns[~batting.columns.isin(removed_columns)]

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
batting.loc[:, selected_columns] = scaler.fit_transform(batting[selected_columns])
# Out:
# <ipython-input-18-65847fba63fb>:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.39130435 0.43478261 0.60869565 ... 0.43478261 0.13043478 0.13043478]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   batting.loc[:, selected_columns] = scaler.fit_transform(batting[selected_columns])
# <ipython-input-18-65847fba63fb>:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.73504274 0.74358974 0.82051282 ... 0.8034188  0.86324786 0.75213675]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   batting.loc[:, selected_columns] = scaler.fit_transform(batting[selected_columns])
# ...

# %%
batting.describe()
# Out:
#                IDfg       Season          Age            G           AB  \
# count   5446.000000  5446.000000  5446.000000  5446.000000  5446.000000
# mean    7736.383033  2014.030665     0.399847     0.648634     0.476418
# std     6506.110600     5.620340     0.163721     0.256406     0.241101
# min        1.000000  2005.000000     0.000000     0.000000     0.000000
# 25%     1908.000000  2009.000000     0.260870     0.461538     0.276978
# 50%     5931.500000  2014.000000     0.391304     0.709402     0.498201
# 75%    12155.000000  2019.000000     0.521739     0.871795     0.685252
# max    33333.000000  2024.000000     1.000000     1.000000     1.000000
#
#                 PA            H           1B           2B           3B  ...  \
# count  5446.000000  5446.000000  5446.000000  5446.000000  5446.000000  ...
# mean      0.477586     0.400583     0.317274     0.387120     0.099275  ...
# std       0.260468     0.200951     0.152578     0.166274     0.103390  ...
# ...

# %%
sfs.fit(batting[selected_columns], batting["Next_WAR"])
# Out:
# SequentialFeatureSelector(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=3, test_size=None),
#                           estimator=Ridge(alpha=1), n_features_to_select=20,
#                           n_jobs=4)

# %%
predictors = list(selected_columns[sfs.get_support()])
predictors
# Out:
# ['Age',
#  '3B',
#  'IBB',
#  'SO',
#  'SH',
#  'CS',
#  'BU',
#  'Pos',
#  'WAR',
#  'Spd',
#  'PH',
#  'Clutch',
#  'FB% (Pitch)',
#  'O-Swing%',
#  'Oppo%',
#  'ISO+',
#  'BABIP+',
#  'LD+%',
#  'Soft%+',
#  'Hard%+']

# %%
def backtest(data, model, predictors, start=5, step=1):
    all_predictions = []

    years = sorted(data["Season"].unique())

    for i in range(start, len(years), step):
        current_year = years[i]

        train = data[data["Season"] < current_year]
        test = data[data["Season"] == current_year]

        model.fit(train[predictors], train["Next_WAR"])

        preds = model.predict(test[predictors])
        preds = pd.Series(preds, index=test.index)
        combined = pd.concat([test["Next_WAR"], preds], axis=1)
        combined.columns = ["actual", "prediction"]

        all_predictions.append(combined)
    return pd.concat(all_predictions)

# %%
predictions = backtest(batting, rr, predictors)
predictions
# Out:
#       actual  prediction
# 5229     0.4    0.702240
# 4340     0.3   -0.158336
# 1210     0.5    2.618875
# 1119     1.5    1.380764
# 1377     1.8    1.667620
# ...      ...         ...
# 6305     0.9    1.023053
# 988      1.8    2.345600
# 6806     0.9    3.329759
# 3975     0.8    1.274603
# 3565     1.0    3.141986
#
# [3995 rows x 2 columns]

# %%
from sklearn.metrics import mean_squared_error

mean_squared_error(predictions["actual"], predictions["prediction"])
# Out:
# 2.6172397111212136

# %%
batting["Next_WAR"].describe()
# Out:
# count    5446.000000
# mean        1.751487
# std         1.945611
# min        -3.100000
# 25%         0.400000
# 50%         1.400000
# 75%         2.800000
# max        11.200000
# Name: Next_WAR, dtype: float64

# %%
2.6118324986594215 ** .5
# Out:
# 1.616116486723473

# %%
def player_history(df):
  df = df.sort_values("Season")

  df["player_season"] = range(0, df.shape[0])
  df["war_corr"] = list(df[["player_season", "WAR"]].expanding().corr().loc[(slice(None), "player_season"), "WAR"])
  df["war_corr"].fillna(1, inplace=True)

  df["war_diff"] = df["WAR"]/df["WAR"].shift(1)
  df["war_diff"].fillna(1, inplace=True)
  df["war_diff"][df["war_diff"] == np.inf] = 1
  return df

batting = batting.groupby("IDfg", group_keys=False).apply(player_history)
# Out:
# Streaming output truncated to the last 5000 lines.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["war_corr"].fillna(1, inplace=True)
# <ipython-input-27-15ba946cfcf4>:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["war_diff"].fillna(1, inplace=True)
# ...

# %%
def group_averages(df):
  return df["WAR"] / df["WAR"].mean()

# %%
batting["war_season"] = batting.groupby("Season", group_keys=False).apply(group_averages)
# Out:
# <ipython-input-29-0b7d260132bb>:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   batting["war_season"] = batting.groupby("Season", group_keys=False).apply(group_averages)

# %%
new_predicters = predictors + ["player_season", "war_corr", "war_season", "war_diff"]

# %%
predictions = backtest(batting, rr, new_predicters)

# %%
mean_squared_error(predictions["actual"], predictions["prediction"])
# Out:
# 2.5510903100271562

# %%
pd.Series(rr.coef_, index=new_predicters).sort_values()
# Out:
# Age             -2.566956
# WAR             -1.989268
# BABIP+          -1.857156
# ISO+            -1.382398
# PH              -0.964897
# BU              -0.946547
# Soft%+          -0.763203
# SO              -0.568763
# O-Swing%        -0.480742
# war_diff        -0.360685
# LD+%            -0.356030
# Clutch          -0.345337
# SH              -0.306705
# 3B              -0.244894
# war_corr        -0.117164
# player_season    0.025078
# FB% (Pitch)      0.070249
# Pos              0.212149
# CS               0.551906
# Oppo%            0.693139
# Spd              1.190282
# IBB              1.260615
# Hard%+           2.320314
# war_season       3.340420
# dtype: float64

# %%
diff = predictions["actual"] - predictions["prediction"]
diff
# Out:
# 5229   -0.518035
# 4340    0.352078
# 1210   -2.224164
# 1119    0.141662
# 1377    0.039422
#           ...
# 6305    0.348284
# 988    -0.005746
# 6806   -1.911893
# 3975   -0.141407
# 3565   -1.670321
# Length: 3995, dtype: float64

# %%
merged = predictions.merge(batting, left_index=True, right_index=True)

# %%
merged["diff"]= (predictions["actual"]-predictions["prediction"]).abs()

# %%
merged[["IDfg", "Name", "Season", "WAR", "Next_WAR", "diff"]].sort_values("diff")
# Out:
#        IDfg               Name  Season       WAR  Next_WAR       diff
# 5558   9874        DJ LeMahieu    2014  0.237762       1.9   0.000037
# 2319  22515       Heliot Ramos    2024  0.377622       1.4   0.000813
# 6596   9774  Christian Vazquez    2023  0.279720       0.8   0.001316
# 6163  10199     Billy Hamilton    2017  0.342657       1.7   0.001539
# 3335  10950        Adam Duvall    2021  0.377622       0.9   0.001707
# ...     ...                ...     ...       ...       ...        ...
# 760    9166       Buster Posey    2010  0.489510       9.8   6.626232
# 76    15640        Aaron Judge    2023  0.545455      11.2   7.575473
# 2339  11579       Bryce Harper    2014  0.328671       9.3   7.586119
# 395   15640        Aaron Judge    2021  0.601399      11.1   7.626746
# 1849    319          Adam Dunn    2012  0.363636       0.4  14.599160
#
# [3995 rows x 6 columns]
